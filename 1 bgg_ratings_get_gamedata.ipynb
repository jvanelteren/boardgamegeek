# %%
import xmltodict
import math
import urllib.request
import itertools
import pandas as pd
import pickle
from sklearn.utils import shuffle
import time

# %%
from urllib.request import urlopen
# the original csv from https://raw.githubusercontent.com/beefsack/bgg-ranking-historicals/master/2017-02-21.csv
# The ID's where used in API calls to retrieve the game reviews
link="https://raw.githubusercontent.com/beefsack/bgg-ranking-historicals/master/2022-01-08.csv"
f = urlopen(link)
games = pd.read_csv(f)
games.describe()
games.sort_values('Users rated',ascending=False,inplace=True)
games[:10]
games.to_csv('2022-01-08.csv')

# %%
len(games)
# Out:
# 21831

# %%
def gen_batches():
    num_batches = len(games)//100
    for b in range(num_batches):
        result = slice(b*100,(b+1)*100)
        if b*100>-1:
            yield result
    yield slice((b+1)*100,len(games)+1)

# %%
def number_rating_pages(game_id):
    url = 'https://www.boardgamegeek.com/xmlapi2/thing?id='+str(game_id)+'&ratingcomments=1'
    u = urllib.request.urlopen(url).read()#The url you want to open
    doc = xmltodict.parse(u)
    return math.ceil(int(doc['items']['item']['comments']['@totalitems'])/100)

# %%
def get_url_result(ids): # given a url of an object and a page, return list of dicts with the comments
    url = 'https://www.boardgamegeek.com/xmlapi2/thing?id='+str(ids)+'&stats=1'
    #url += '&&page='+str(p)
    u = urllib.request.urlopen(url).read()#The url you want to open
    doc = xmltodict.parse(u)
    return doc

# %%
def process_game_result(url_result):
    games = []
    for g in url_result['items']['item']:
        games.append(process_game(g))
    return games

# %%
def process_game(a):
    res = {}
    for k in a.keys():
        if k == '@type': res['type']=a[k]
        if k == '@id': res['id']=a[k]
        if k == 'thumbnail': res['thumbnail']=a[k]
        if k == 'image': res['image']=a[k]
        if k == 'name':
            if isinstance(a[k], list):
                for item in a[k]:
                    if item['@type'] in res.keys():
                        res[item['@type']].append(item['@value'])
                    else:
                        res[item['@type']] = [item['@value']]  
            else:
                res[a[k]['@type']] = [a[k]['@value']]


        if k == 'description': res[k]=a[k]
        if k == 'yearpublished': res[k]=a[k]['@value']
        if k == 'minplayers': res[k]=a[k]['@value'] 
        if k == 'maxplayers': res[k]=a[k]['@value'] 
        if k == 'playingtime': res[k]=a[k]['@value']        
        if k == 'minplaytime': res[k]=a[k]['@value']
        if k == 'maxplaytime': res[k]=a[k]['@value']
        if k == 'minage': res[k]=a[k]['@value']
        if k == 'link': 
            for item in a[k]:
                if item['@type'] in res.keys():
                    res[item['@type']].append(item['@value'])
                else:
                    res[item['@type']] = [item['@value']]
        if k == 'statistics':

            for kk in a[k]['ratings'].keys():
                if kk == 'ranks':
                    if isinstance(a[k]['ratings']['ranks']['rank'], list):
                        for r in a[k]['ratings']['ranks']['rank']:
                            res[r['@friendlyname']] = r['@value']    
                    else:
                        res[a[k]['ratings']['ranks']['rank']['@friendlyname']] = a[k]['ratings']['ranks']['rank']['@value']    
                else:
                    res[kk] = a[k]['ratings'][kk]['@value']
        if k == 'poll': 
            for p in a[k]:
                if p['@name'] == 'suggested_numplayers':
                    if 'results' in p.keys():
                        res['suggested_num_players']= p['results'] # Added this line
                    
                        # if isinstance(p['results'], list):

                        #     for num in p['results']:
                        #         suggestion = []
                        #         if isinstance(num['result'], list):
                        #             for s in num['result']: suggestion.append(s['@numvotes'])
                        #             res['suggested_num_players='+num['@numplayers']]=suggestion
                        #         else:
                        #             res['suggested_num_players='+num['result']['@numplayers']]=num['result']['@numvotes']
                        # else:
                        #     if 'result' in p['results'].keys():
                        #         if isinstance(p['results']['result'], list):
                        #             suggestion = []
                        #             for s in p['results']['result']: suggestion.append(s['@numvotes'])
                        #             res['suggested_num_players='+p['results']['@numplayers']]=suggestion
                        #         else:
                        #             res['suggested_num_players='+p['results']['result']['@numplayers']]=p['results']['result']['@numvotes']
                if p['@name'] == 'suggested_playerage':
                    if 'results' in p.keys():
                        res['suggested_playerage']=p['results']['result']
                        #                         if isinstance(p['results']['result'], list):                    
                        #                             for l in p['results']['result']: res['suggested_playerage='+l['@value']]=l['@numvotes']
                        #                         else:
                        #                             res['suggested_playerage='+p['results']['result']]=p['results']['result']['@numvotes']

                if p['@name'] == 'language_dependence':
                    if 'results' in p.keys():
                        res['suggested_language_dependence']=p['results']['result']
                        #                         if isinstance(p['results']['result'], list):
                        #                             for l in p['results']['result']: res['suggested_language_dependence='+l['@value']]=l['@numvotes']
                        #                         else:
                        #                             res['suggested_language_dependence='+p['results']['result']['@value']]=p['results']['result']['@numvotes']

    return res

# %%
game_list = []
game_generator = gen_batches()

# get all games, but do this per batch of 100 games
for batch in game_generator: 
    for i in range(5):
        try:
            print('new batch,', batch)
            # list of games
            games_in_batch = list(games['ID'][batch])
            
            print('next query for {} games'.format(len(games_in_batch)))
            # convert list of current games to url input
            ids = ','.join(str(g) for g in games_in_batch)
            #query API and parse to dictionary
            url_result = get_url_result(ids)
            print('data retrieved')
            #print('to remove',removelist)
            game_list += process_game_result(url_result)
            time.sleep(5)
            break
        except Exception as e:
            print (e,i,batch)
            time.sleep(30)
with open('games.pickle', 'wb') as handle:
    pickle.dump(game_list, handle, protocol=pickle.HIGHEST_PROTOCOL)
print('all done')
# Out:
# new batch, slice(0, 100, None)
# next query for 100 games
# data retrieved
# new batch, slice(100, 200, None)
# next query for 100 games
# data retrieved
# new batch, slice(200, 300, None)
# next query for 100 games
# data retrieved
# new batch, slice(300, 400, None)
# next query for 100 games
# data retrieved
# new batch, slice(400, 500, None)
# next query for 100 games
# data retrieved
# new batch, slice(500, 600, None)
# next query for 100 games
# data retrieved
# new batch, slice(600, 700, None)
# next query for 100 games
# data retrieved
# new batch, slice(700, 800, None)
# next query for 100 games
# data retrieved
# new batch, slice(800, 900, None)
# next query for 100 games
# data retrieved
# new batch, slice(900, 1000, None)
# next query for 100 games
# data retrieved
# new batch, slice(1000, 1100, None)
# next query for 100 games
# data retrieved
# new batch, slice(1100, 1200, None)
# next query for 100 games
# data retrieved
# new batch, slice(1200, 1300, None)
# next query for 100 games
# data retrieved
# new batch, slice(1300, 1400, None)
# next query for 100 games
# data retrieved
# new batch, slice(1400, 1500, None)
# next query for 100 games
# data retrieved
# new batch, slice(1500, 1600, None)
# next query for 100 games
# data retrieved
# new batch, slice(1600, 1700, None)
# next query for 100 games
# data retrieved
# new batch, slice(1700, 1800, None)
# next query for 100 games
# data retrieved
# new batch, slice(1800, 1900, None)
# next query for 100 games
# data retrieved
# new batch, slice(1900, 2000, None)
# next query for 100 games
# data retrieved
# new batch, slice(2000, 2100, None)
# next query for 100 games
# data retrieved
# new batch, slice(2100, 2200, None)
# next query for 100 games
# data retrieved
# new batch, slice(2200, 2300, None)
# next query for 100 games
# data retrieved
# new batch, slice(2300, 2400, None)
# next query for 100 games
# data retrieved
# new batch, slice(2400, 2500, None)
# next query for 100 games
# data retrieved
# new batch, slice(2500, 2600, None)
# next query for 100 games
# data retrieved
# new batch, slice(2600, 2700, None)
# next query for 100 games
# data retrieved
# new batch, slice(2700, 2800, None)
# next query for 100 games
# data retrieved
# new batch, slice(2800, 2900, None)
# next query for 100 games
# data retrieved
# new batch, slice(2900, 3000, None)
# next query for 100 games
# data retrieved
# new batch, slice(3000, 3100, None)
# next query for 100 games
# data retrieved
# new batch, slice(3100, 3200, None)
# next query for 100 games
# data retrieved
# new batch, slice(3200, 3300, None)
# next query for 100 games
# data retrieved
# new batch, slice(3300, 3400, None)
# next query for 100 games
# data retrieved
# new batch, slice(3400, 3500, None)
# next query for 100 games
# data retrieved
# new batch, slice(3500, 3600, None)
# next query for 100 games
# data retrieved
# new batch, slice(3600, 3700, None)
# next query for 100 games
# data retrieved
# new batch, slice(3700, 3800, None)
# next query for 100 games
# data retrieved
# new batch, slice(3800, 3900, None)
# next query for 100 games
# data retrieved
# new batch, slice(3900, 4000, None)
# next query for 100 games
# data retrieved
# new batch, slice(4000, 4100, None)
# next query for 100 games
# data retrieved
# new batch, slice(4100, 4200, None)
# next query for 100 games
# data retrieved
# new batch, slice(4200, 4300, None)
# next query for 100 games
# data retrieved
# new batch, slice(4300, 4400, None)
# next query for 100 games
# data retrieved
# new batch, slice(4400, 4500, None)
# next query for 100 games
# data retrieved
# new batch, slice(4500, 4600, None)
# next query for 100 games
# data retrieved
# new batch, slice(4600, 4700, None)
# next query for 100 games
# data retrieved
# new batch, slice(4700, 4800, None)
# next query for 100 games
# data retrieved
# new batch, slice(4800, 4900, None)
# next query for 100 games
# data retrieved
# new batch, slice(4900, 5000, None)
# next query for 100 games
# data retrieved
# new batch, slice(5000, 5100, None)
# next query for 100 games
# data retrieved
# new batch, slice(5100, 5200, None)
# next query for 100 games
# data retrieved
# new batch, slice(5200, 5300, None)
# next query for 100 games
# data retrieved
# new batch, slice(5300, 5400, None)
# next query for 100 games
# data retrieved
# new batch, slice(5400, 5500, None)
# next query for 100 games
# data retrieved
# new batch, slice(5500, 5600, None)
# next query for 100 games
# data retrieved
# new batch, slice(5600, 5700, None)
# next query for 100 games
# data retrieved
# new batch, slice(5700, 5800, None)
# next query for 100 games
# data retrieved
# new batch, slice(5800, 5900, None)
# next query for 100 games
# data retrieved
# new batch, slice(5900, 6000, None)
# next query for 100 games
# data retrieved
# new batch, slice(6000, 6100, None)
# next query for 100 games
# data retrieved
# new batch, slice(6100, 6200, None)
# next query for 100 games
# data retrieved
# new batch, slice(6200, 6300, None)
# next query for 100 games
# data retrieved
# new batch, slice(6300, 6400, None)
# next query for 100 games
# data retrieved
# new batch, slice(6400, 6500, None)
# next query for 100 games
# data retrieved
# new batch, slice(6500, 6600, None)
# next query for 100 games
# data retrieved
# new batch, slice(6600, 6700, None)
# next query for 100 games
# data retrieved
# new batch, slice(6700, 6800, None)
# next query for 100 games
# data retrieved
# new batch, slice(6800, 6900, None)
# next query for 100 games
# data retrieved
# new batch, slice(6900, 7000, None)
# next query for 100 games
# data retrieved
# new batch, slice(7000, 7100, None)
# next query for 100 games
# data retrieved
# new batch, slice(7100, 7200, None)
# next query for 100 games
# data retrieved
# new batch, slice(7200, 7300, None)
# next query for 100 games
# data retrieved
# new batch, slice(7300, 7400, None)
# next query for 100 games
# data retrieved
# new batch, slice(7400, 7500, None)
# next query for 100 games
# data retrieved
# new batch, slice(7500, 7600, None)
# next query for 100 games
# data retrieved
# new batch, slice(7600, 7700, None)
# next query for 100 games
# data retrieved
# new batch, slice(7700, 7800, None)
# next query for 100 games
# data retrieved
# new batch, slice(7800, 7900, None)
# next query for 100 games
# data retrieved
# new batch, slice(7900, 8000, None)
# next query for 100 games
# data retrieved
# new batch, slice(8000, 8100, None)
# next query for 100 games
# data retrieved
# new batch, slice(8100, 8200, None)
# next query for 100 games
# data retrieved
# new batch, slice(8200, 8300, None)
# next query for 100 games
# data retrieved
# new batch, slice(8300, 8400, None)
# next query for 100 games
# data retrieved
# new batch, slice(8400, 8500, None)
# next query for 100 games
# data retrieved
# new batch, slice(8500, 8600, None)
# next query for 100 games
# data retrieved
# new batch, slice(8600, 8700, None)
# next query for 100 games
# data retrieved
# new batch, slice(8700, 8800, None)
# next query for 100 games
# data retrieved
# new batch, slice(8800, 8900, None)
# next query for 100 games
# data retrieved
# new batch, slice(8900, 9000, None)
# next query for 100 games
# data retrieved
# new batch, slice(9000, 9100, None)
# next query for 100 games
# data retrieved
# new batch, slice(9100, 9200, None)
# next query for 100 games
# data retrieved
# new batch, slice(9200, 9300, None)
# next query for 100 games
# data retrieved
# new batch, slice(9300, 9400, None)
# next query for 100 games
# data retrieved
# new batch, slice(9400, 9500, None)
# next query for 100 games
# data retrieved
# new batch, slice(9500, 9600, None)
# next query for 100 games
# data retrieved
# new batch, slice(9600, 9700, None)
# next query for 100 games
# data retrieved
# new batch, slice(9700, 9800, None)
# next query for 100 games
# data retrieved
# new batch, slice(9800, 9900, None)
# next query for 100 games
# data retrieved
# new batch, slice(9900, 10000, None)
# next query for 100 games
# data retrieved
# new batch, slice(10000, 10100, None)
# next query for 100 games
# data retrieved
# new batch, slice(10100, 10200, None)
# next query for 100 games
# data retrieved
# new batch, slice(10200, 10300, None)
# next query for 100 games
# data retrieved
# new batch, slice(10300, 10400, None)
# next query for 100 games
# data retrieved
# new batch, slice(10400, 10500, None)
# next query for 100 games
# data retrieved
# new batch, slice(10500, 10600, None)
# next query for 100 games
# data retrieved
# new batch, slice(10600, 10700, None)
# next query for 100 games
# data retrieved
# new batch, slice(10700, 10800, None)
# next query for 100 games
# data retrieved
# new batch, slice(10800, 10900, None)
# next query for 100 games
# data retrieved
# new batch, slice(10900, 11000, None)
# next query for 100 games
# data retrieved
# new batch, slice(11000, 11100, None)
# next query for 100 games
# data retrieved
# new batch, slice(11100, 11200, None)
# next query for 100 games
# data retrieved
# new batch, slice(11200, 11300, None)
# next query for 100 games
# data retrieved
# new batch, slice(11300, 11400, None)
# next query for 100 games
# data retrieved
# new batch, slice(11400, 11500, None)
# next query for 100 games
# data retrieved
# new batch, slice(11500, 11600, None)
# next query for 100 games
# data retrieved
# new batch, slice(11600, 11700, None)
# next query for 100 games
# data retrieved
# new batch, slice(11700, 11800, None)
# next query for 100 games
# data retrieved
# new batch, slice(11800, 11900, None)
# next query for 100 games
# data retrieved
# new batch, slice(11900, 12000, None)
# next query for 100 games
# data retrieved
# new batch, slice(12000, 12100, None)
# next query for 100 games
# data retrieved
# new batch, slice(12100, 12200, None)
# next query for 100 games
# data retrieved
# new batch, slice(12200, 12300, None)
# next query for 100 games
# data retrieved
# new batch, slice(12300, 12400, None)
# next query for 100 games
# data retrieved
# new batch, slice(12400, 12500, None)
# next query for 100 games
# data retrieved
# new batch, slice(12500, 12600, None)
# next query for 100 games
# data retrieved
# new batch, slice(12600, 12700, None)
# next query for 100 games
# data retrieved
# new batch, slice(12700, 12800, None)
# next query for 100 games
# data retrieved
# new batch, slice(12800, 12900, None)
# next query for 100 games
# data retrieved
# new batch, slice(12900, 13000, None)
# next query for 100 games
# data retrieved
# new batch, slice(13000, 13100, None)
# next query for 100 games
# data retrieved
# new batch, slice(13100, 13200, None)
# next query for 100 games
# data retrieved
# new batch, slice(13200, 13300, None)
# next query for 100 games
# data retrieved
# new batch, slice(13300, 13400, None)
# next query for 100 games
# data retrieved
# new batch, slice(13400, 13500, None)
# next query for 100 games
# data retrieved
# new batch, slice(13500, 13600, None)
# next query for 100 games
# data retrieved
# new batch, slice(13600, 13700, None)
# next query for 100 games
# data retrieved
# new batch, slice(13700, 13800, None)
# next query for 100 games
# data retrieved
# new batch, slice(13800, 13900, None)
# next query for 100 games
# data retrieved
# new batch, slice(13900, 14000, None)
# next query for 100 games
# data retrieved
# new batch, slice(14000, 14100, None)
# next query for 100 games
# data retrieved
# new batch, slice(14100, 14200, None)
# next query for 100 games
# data retrieved
# new batch, slice(14200, 14300, None)
# next query for 100 games
# data retrieved
# new batch, slice(14300, 14400, None)
# next query for 100 games
# data retrieved
# new batch, slice(14400, 14500, None)
# next query for 100 games
# data retrieved
# new batch, slice(14500, 14600, None)
# next query for 100 games
# data retrieved
# new batch, slice(14600, 14700, None)
# next query for 100 games
# data retrieved
# new batch, slice(14700, 14800, None)
# next query for 100 games
# data retrieved
# new batch, slice(14800, 14900, None)
# next query for 100 games
# data retrieved
# new batch, slice(14900, 15000, None)
# next query for 100 games
# data retrieved
# new batch, slice(15000, 15100, None)
# next query for 100 games
# data retrieved
# new batch, slice(15100, 15200, None)
# next query for 100 games
# data retrieved
# new batch, slice(15200, 15300, None)
# next query for 100 games
# data retrieved
# new batch, slice(15300, 15400, None)
# next query for 100 games
# data retrieved
# new batch, slice(15400, 15500, None)
# next query for 100 games
# data retrieved
# new batch, slice(15500, 15600, None)
# next query for 100 games
# data retrieved
# new batch, slice(15600, 15700, None)
# next query for 100 games
# data retrieved
# new batch, slice(15700, 15800, None)
# next query for 100 games
# data retrieved
# new batch, slice(15800, 15900, None)
# next query for 100 games
# data retrieved
# new batch, slice(15900, 16000, None)
# next query for 100 games
# data retrieved
# new batch, slice(16000, 16100, None)
# next query for 100 games
# data retrieved
# new batch, slice(16100, 16200, None)
# next query for 100 games
# data retrieved
# new batch, slice(16200, 16300, None)
# next query for 100 games
# data retrieved
# new batch, slice(16300, 16400, None)
# next query for 100 games
# data retrieved
# new batch, slice(16400, 16500, None)
# next query for 100 games
# data retrieved
# new batch, slice(16500, 16600, None)
# next query for 100 games
# data retrieved
# new batch, slice(16600, 16700, None)
# next query for 100 games
# data retrieved
# new batch, slice(16700, 16800, None)
# next query for 100 games
# data retrieved
# new batch, slice(16800, 16900, None)
# next query for 100 games
# data retrieved
# new batch, slice(16900, 17000, None)
# next query for 100 games
# data retrieved
# new batch, slice(17000, 17100, None)
# next query for 100 games
# data retrieved
# new batch, slice(17100, 17200, None)
# next query for 100 games
# data retrieved
# string indices must be integers 0 slice(17100, 17200, None)
# new batch, slice(17100, 17200, None)
# next query for 100 games
# data retrieved
# string indices must be integers 1 slice(17100, 17200, None)
# new batch, slice(17100, 17200, None)
# next query for 100 games
# data retrieved
# string indices must be integers 2 slice(17100, 17200, None)
# new batch, slice(17100, 17200, None)
# next query for 100 games
# data retrieved
# string indices must be integers 3 slice(17100, 17200, None)
# new batch, slice(17100, 17200, None)
# next query for 100 games
# data retrieved
# string indices must be integers 4 slice(17100, 17200, None)
# new batch, slice(17200, 17300, None)
# next query for 100 games
# data retrieved
# new batch, slice(17300, 17400, None)
# next query for 100 games
# data retrieved
# new batch, slice(17400, 17500, None)
# next query for 100 games
# data retrieved
# new batch, slice(17500, 17600, None)
# next query for 100 games
# data retrieved
# new batch, slice(17600, 17700, None)
# next query for 100 games
# data retrieved
# new batch, slice(17700, 17800, None)
# next query for 100 games
# data retrieved
# new batch, slice(17800, 17900, None)
# next query for 100 games
# data retrieved
# new batch, slice(17900, 18000, None)
# next query for 100 games
# data retrieved
# new batch, slice(18000, 18100, None)
# next query for 100 games
# data retrieved
# new batch, slice(18100, 18200, None)
# next query for 100 games
# data retrieved
# new batch, slice(18200, 18300, None)
# next query for 100 games
# data retrieved
# new batch, slice(18300, 18400, None)
# next query for 100 games
# data retrieved
# new batch, slice(18400, 18500, None)
# next query for 100 games
# data retrieved
# new batch, slice(18500, 18600, None)
# next query for 100 games
# data retrieved
# string indices must be integers 0 slice(18500, 18600, None)
# new batch, slice(18500, 18600, None)
# next query for 100 games
# data retrieved
# string indices must be integers 1 slice(18500, 18600, None)
# new batch, slice(18500, 18600, None)
# next query for 100 games
# data retrieved
# string indices must be integers 2 slice(18500, 18600, None)
# new batch, slice(18500, 18600, None)
# next query for 100 games
# data retrieved
# string indices must be integers 3 slice(18500, 18600, None)
# new batch, slice(18500, 18600, None)
# next query for 100 games
# data retrieved
# string indices must be integers 4 slice(18500, 18600, None)
# new batch, slice(18600, 18700, None)
# next query for 100 games
# data retrieved
# new batch, slice(18700, 18800, None)
# next query for 100 games
# data retrieved
# new batch, slice(18800, 18900, None)
# next query for 100 games
# data retrieved
# new batch, slice(18900, 19000, None)
# next query for 100 games
# data retrieved
# new batch, slice(19000, 19100, None)
# next query for 100 games
# data retrieved
# new batch, slice(19100, 19200, None)
# next query for 100 games
# data retrieved
# new batch, slice(19200, 19300, None)
# next query for 100 games
# data retrieved
# new batch, slice(19300, 19400, None)
# next query for 100 games
# data retrieved
# new batch, slice(19400, 19500, None)
# next query for 100 games
# data retrieved
# new batch, slice(19500, 19600, None)
# next query for 100 games
# data retrieved
# new batch, slice(19600, 19700, None)
# next query for 100 games
# data retrieved
# new batch, slice(19700, 19800, None)
# next query for 100 games
# data retrieved
# new batch, slice(19800, 19900, None)
# next query for 100 games
# data retrieved
# new batch, slice(19900, 20000, None)
# next query for 100 games
# data retrieved
# new batch, slice(20000, 20100, None)
# next query for 100 games
# data retrieved
# new batch, slice(20100, 20200, None)
# next query for 100 games
# data retrieved
# new batch, slice(20200, 20300, None)
# next query for 100 games
# data retrieved
# new batch, slice(20300, 20400, None)
# next query for 100 games
# data retrieved
# new batch, slice(20400, 20500, None)
# next query for 100 games
# data retrieved
# new batch, slice(20500, 20600, None)
# next query for 100 games
# data retrieved
# new batch, slice(20600, 20700, None)
# next query for 100 games
# data retrieved
# new batch, slice(20700, 20800, None)
# next query for 100 games
# data retrieved
# new batch, slice(20800, 20900, None)
# next query for 100 games
# data retrieved
# new batch, slice(20900, 21000, None)
# next query for 100 games
# data retrieved
# new batch, slice(21000, 21100, None)
# next query for 100 games
# data retrieved
# new batch, slice(21100, 21200, None)
# next query for 100 games
# data retrieved
# new batch, slice(21200, 21300, None)
# next query for 100 games
# data retrieved
# new batch, slice(21300, 21400, None)
# next query for 100 games
# data retrieved
# new batch, slice(21400, 21500, None)
# next query for 100 games
# data retrieved
# new batch, slice(21500, 21600, None)
# next query for 100 games
# data retrieved
# new batch, slice(21600, 21700, None)
# next query for 100 games
# data retrieved
# new batch, slice(21700, 21800, None)
# next query for 100 games
# data retrieved
# new batch, slice(21800, 21832, None)
# next query for 31 games
# data retrieved
# all done

# %%
games= pd.DataFrame(game_list)
pd.options.display.max_rows = 200
games['primary']=games['primary'].map(lambda x: str(x)[2:-2])
games.to_csv(r'games_detailed_info.csv')
games.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\GEBRUI~1\AppData\Local\Temp/ipykernel_24816/485584277.py in <module>
# ----> 1 games= pd.DataFrame(game_list)
#       2 pd.options.display.max_rows = 200
#       3 games['primary']=games['primary'].map(lambda x: str(x)[2:-2])
#       4 games.to_csv(r'games_detailed_info.csv')
#       5 games.head()
#
# NameError: name 'pd' is not defined
