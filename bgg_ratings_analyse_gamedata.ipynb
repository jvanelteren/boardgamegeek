# %%
import xmltodict
import math
import urllib.request
import itertools
import pandas as pd
import pickle
from sklearn.utils import shuffle
import time

# %%
games= pd.read_csv('games_detailed_info.csv')
pd.options.display.max_rows = 200
# Out:
# C:\Users\Gebruiker\AppData\Roaming\Python\Python310\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (29,48) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
categorical =

# %%
games.head().T
# Out:
#                                                                                0  \
# Unnamed: 0                                                                     0
# type                                                                   boardgame
# id                                                                         30549
# thumbnail                      https://cf.geekdo-images.com/S3ybV1LAp-8SnHIXL...
# image                          https://cf.geekdo-images.com/S3ybV1LAp-8SnHIXL...
# primary                                                                 Pandemic
# alternate                      ['EPIZOotic', 'Pandemia', 'Pandemia 10 Anivers...
# description                    In Pandemic, several virulent diseases have br...
# yearpublished                                                               2008
# minplayers                                                                     2
# maxplayers                                                                     4
# ...

# %%
games.describe()
# Out:
#          Unnamed: 0             id  yearpublished    minplayers    maxplayers  \
# count  21631.000000   21631.000000   21631.000000  21631.000000  21631.000000
# mean   10815.000000  118133.093847    1986.094910      2.007027      5.709491
# std     6244.476172  105310.419253     210.042496      0.688957     15.102385
# min        0.000000       1.000000   -3500.000000      0.000000      0.000000
# 25%     5407.500000   12280.500000    2001.000000      2.000000      4.000000
# 50%    10815.000000  105187.000000    2011.000000      2.000000      4.000000
# 75%    16222.500000  207013.000000    2017.000000      2.000000      6.000000
# max    21630.000000  350992.000000    2023.000000     10.000000    999.000000
#
#         playingtime   minplaytime   maxplaytime        minage     usersrated  \
# count  21631.000000  21631.000000  21631.000000  21631.000000   21631.000000
# mean      90.509177     63.647774     90.509177      9.611391     875.000693
# ...

# %% [markdown]
# ## Preprocessing

# %%
test = games.loc[games['primary'] == 'Kanban EV']['suggested_language_dependence'].values[0]
test
# Out:
# "[OrderedDict([('@level', '91'), ('@value', 'No necessary in-game text'), ('@numvotes', '2')]), OrderedDict([('@level', '92'), ('@value', 'Some necessary text - easily memorized or small crib sheet'), ('@numvotes', '0')]), OrderedDict([('@level', '93'), ('@value', 'Moderate in-game text - needs crib sheet or paste ups'), ('@numvotes', '0')]), OrderedDict([('@level', '94'), ('@value', 'Extensive use of text - massive conversion needed to be playable'), ('@numvotes', '0')]), OrderedDict([('@level', '95'), ('@value', 'Unplayable in another language'), ('@numvotes', '0')])]"

# %%
test = "{[('@level', '95'), ('value', 'Unplayable in another language'), ('numvotes', '0')]}"

# %%
import ast
ast.literal_eval(test)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\GEBRUI~1\AppData\Local\Temp/ipykernel_5340/1609812252.py in <module>
#       1 import ast
# ----> 2 ast.literal_eval(test)
#
# C:\Program Files\Python310\lib\ast.py in literal_eval(node_or_string)
#     106                     return left - right
#     107         return _convert_signed_num(node)
# --> 108     return _convert(node_or_string)
#     109
#     110
#
# C:\Program Files\Python310\lib\ast.py in _convert(node)
#      88             return list(map(_convert, node.elts))
#      89         elif isinstance(node, Set):
# ---> 90             return set(map(_convert, node.elts))
#      91         elif (isinstance(node, Call) and isinstance(node.func, Name) and
#      92               node.func.id == 'set' and node.args == node.keywords == []):
#
# TypeError: unhashable type: 'list'

# %%
games['iskick'] = games['boardgamefamily'].str.contains('Kickstarter')

# %%
games.groupby('iskick')['average'].agg('mean')
# Out:
# iskick
# False    6.413012
# True     6.884485
# Name: average, dtype: float64

# %% [markdown]
# Kickstarter games get a score about 0.4 points higher
